# %% [markdown]
# ### 假设模型：多元线性回归

# %% [markdown]
# 变量一（+）：参与意愿（消费者对于线上网红带领的营销活动的参与意愿）<br>
# 变量二（+）：自我反射（消费者能够在网红神圣反射自身的程度）<br>
# 变量三（+）：信任（消费者对于网红的信任程度）<br>
# 因变量：消费者对于网红营销活动的参与

# %% [markdown]
# ### 消费者分层：阶级聚类

# %% [markdown]
# 分层框架：Marketing Segmentation
#
# 地理变量（未使用，因研究范围框定）
#
# 基本变量
# 1. 性别
# 2. 教育
# 3. 收入
#
# 行为变量
# 1. 社交重要性
# 2. 关注的网红数
# 3. 社媒使用频率
#
# 心理变量
# 1. 保持更新程度
# 2. 对新鲜事物的接受程度
# 3. 社交外向性

# %% [markdown]
# ### 结果报告
